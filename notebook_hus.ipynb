# %%
import pandas as pd

# %%
country_data = pd.read_csv('life_expectancy_by_country.csv')
country_data
# Out:
#       country_code country_name  year   value
# 0              ABW        Aruba  1960  64.152
# 1              ABW        Aruba  1961  64.537
# 2              ABW        Aruba  1962  64.752
# 3              ABW        Aruba  1963  65.132
# 4              ABW        Aruba  1964  65.294
# ...            ...          ...   ...     ...
# 15201          ZWE     Zimbabwe  2016  60.306
# 15202          ZWE     Zimbabwe  2017  60.709
# 15203          ZWE     Zimbabwe  2018  61.414
# 15204          ZWE     Zimbabwe  2019  61.292
# 15205          ZWE     Zimbabwe  2020  61.124
#
# [15206 rows x 4 columns]

# %%
region_list = ['Africa Eastern and Southern', 'Africa Western and Central', 'Central Europe and the Baltics', 'Caribbean small states', 'East Asia & Pacific', 'Europe & Central Asia', 'Euro area', 'European Union', 'Latin America & Caribbean', 'Middle East & North Africa', 'North America', 'Pacific island small states', 'South Asia', 'Sub-Saharan Africa']

# %%
# remove rows that are not in the region list
country_data = country_data[country_data['country_name'].isin(region_list)]
country_data
# Out:
#       country_code                 country_name  year      value
# 61             AFE  Africa Eastern and Southern  1960  44.085552
# 62             AFE  Africa Eastern and Southern  1961  44.386697
# 63             AFE  Africa Eastern and Southern  1962  44.752182
# 64             AFE  Africa Eastern and Southern  1963  44.913159
# 65             AFE  Africa Eastern and Southern  1964  45.479043
# ...            ...                          ...   ...        ...
# 12347          SSF           Sub-Saharan Africa  2016  60.069021
# 12348          SSF           Sub-Saharan Africa  2017  60.477135
# 12349          SSF           Sub-Saharan Africa  2018  60.863024
# 12350          SSF           Sub-Saharan Africa  2019  61.244287
# 12351          SSF           Sub-Saharan Africa  2020  60.848891
#
# [854 rows x 4 columns]

# %%
# remove rows that are not years 1960, 1980, 2000, 2020
country_data = country_data[country_data['year'].isin([1960, 1980, 2000, 2020])]

# %%
# reset index
country_data = country_data.reset_index(drop=True)
country_data
# Out:
#    country_code                    country_name  year      value
# 0           AFE     Africa Eastern and Southern  1960  44.085552
# 1           AFE     Africa Eastern and Southern  1980  49.636538
# 2           AFE     Africa Eastern and Southern  2000  51.964481
# 3           AFE     Africa Eastern and Southern  2020  63.313856
# 4           AFW      Africa Western and Central  1960  37.845152
# 5           AFW      Africa Western and Central  1980  47.015239
# 6           AFW      Africa Western and Central  2000  50.221954
# 7           AFW      Africa Western and Central  2020  57.226373
# 8           CEB  Central Europe and the Baltics  1960  67.933952
# 9           CEB  Central Europe and the Baltics  1980  69.888985
# 10          CEB  Central Europe and the Baltics  2000  72.719725
# 11          CEB  Central Europe and the Baltics  2020  76.144034
# 12          CSS          Caribbean small states  1960  61.952121
# 13          CSS          Caribbean small states  1980  67.350540
# 14          CSS          Caribbean small states  2000  69.575544
# 15          CSS          Caribbean small states  2020  72.574882
# 16          EAS             East Asia & Pacific  1960  41.641928
# 17          EAS             East Asia & Pacific  1980  64.724662
# 18          EAS             East Asia & Pacific  2000  71.552687
# 19          EAS             East Asia & Pacific  2020  76.762681
# 20          ECS           Europe & Central Asia  1960  67.514086
# 21          ECS           Europe & Central Asia  1980  70.284901
# 22          ECS           Europe & Central Asia  2000  73.132098
# 23          ECS           Europe & Central Asia  2020  77.025324
# 24          EMU                       Euro area  1960  69.284294
# 25          EMU                       Euro area  1980  73.580654
# 26          EMU                       Euro area  2000  78.270835
# 27          EMU                       Euro area  2020  81.537122
# 28          EUU                  European Union  1960  69.037606
# 29          EUU                  European Union  1980  72.789606
# 30          EUU                  European Union  2000  77.075317
# 31          EUU                  European Union  2020  80.465037
# 32          LCN       Latin America & Caribbean  1960  55.146440
# 33          LCN       Latin America & Caribbean  1980  63.681366
# 34          LCN       Latin America & Caribbean  2000  71.227714
# 35          LCN       Latin America & Caribbean  2020  73.038409
# 36          MEA      Middle East & North Africa  1960  44.757573
# 37          MEA      Middle East & North Africa  1980  58.571006
# 38          MEA      Middle East & North Africa  2000  69.282178
# 39          MEA      Middle East & North Africa  2020  72.951079
# 40          NAC                   North America  1960  69.893606
# 41          NAC                   North America  1980  73.752431
# 42          NAC                   North America  2000  76.881996
# 43          NAC                   North America  2020  77.741163
# 44          PSS     Pacific island small states  1960  54.526438
# 45          PSS     Pacific island small states  1980  62.898881
# 46          PSS     Pacific island small states  2000  67.400452
# 47          PSS     Pacific island small states  2020  69.470610
# 48          SAS                      South Asia  1960  45.104840
# 49          SAS                      South Asia  1980  53.759807
# 50          SAS                      South Asia  2000  62.892973
# 51          SAS                      South Asia  2020  69.748331
# 52          SSF              Sub-Saharan Africa  1960  41.422546
# 53          SSF              Sub-Saharan Africa  1980  48.572456
# 54          SSF              Sub-Saharan Africa  2000  51.264545
# 55          SSF              Sub-Saharan Africa  2020  60.848891

# %%
# add columns 1960, 1980, 2000, 2020 with values from value column corresponding to year
country_data['1960'] = country_data['value'][country_data['year'] == 1960]

# %%
country_data['1980'] = country_data['value'][country_data['year'] == 1980]
country_data['2000'] = country_data['value'][country_data['year'] == 2000]
country_data['2020'] = country_data['value'][country_data['year'] == 2020]

# %%
country_data
# Out:
#    country_code                    country_name  year      value       1960  \
# 0           AFE     Africa Eastern and Southern  1960  44.085552  44.085552
# 1           AFE     Africa Eastern and Southern  1980  49.636538        NaN
# 2           AFE     Africa Eastern and Southern  2000  51.964481        NaN
# 3           AFE     Africa Eastern and Southern  2020  63.313856        NaN
# 4           AFW      Africa Western and Central  1960  37.845152  37.845152
# 5           AFW      Africa Western and Central  1980  47.015239        NaN
# 6           AFW      Africa Western and Central  2000  50.221954        NaN
# 7           AFW      Africa Western and Central  2020  57.226373        NaN
# 8           CEB  Central Europe and the Baltics  1960  67.933952  67.933952
# 9           CEB  Central Europe and the Baltics  1980  69.888985        NaN
# 10          CEB  Central Europe and the Baltics  2000  72.719725        NaN
# 11          CEB  Central Europe and the Baltics  2020  76.144034        NaN
# 12          CSS          Caribbean small states  1960  61.952121  61.952121
# 13          CSS          Caribbean small states  1980  67.350540        NaN
# 14          CSS          Caribbean small states  2000  69.575544        NaN
# 15          CSS          Caribbean small states  2020  72.574882        NaN
# 16          EAS             East Asia & Pacific  1960  41.641928  41.641928
# 17          EAS             East Asia & Pacific  1980  64.724662        NaN
# 18          EAS             East Asia & Pacific  2000  71.552687        NaN
# 19          EAS             East Asia & Pacific  2020  76.762681        NaN
# 20          ECS           Europe & Central Asia  1960  67.514086  67.514086
# 21          ECS           Europe & Central Asia  1980  70.284901        NaN
# 22          ECS           Europe & Central Asia  2000  73.132098        NaN
# 23          ECS           Europe & Central Asia  2020  77.025324        NaN
# 24          EMU                       Euro area  1960  69.284294  69.284294
# 25          EMU                       Euro area  1980  73.580654        NaN
# 26          EMU                       Euro area  2000  78.270835        NaN
# 27          EMU                       Euro area  2020  81.537122        NaN
# 28          EUU                  European Union  1960  69.037606  69.037606
# 29          EUU                  European Union  1980  72.789606        NaN
# 30          EUU                  European Union  2000  77.075317        NaN
# 31          EUU                  European Union  2020  80.465037        NaN
# 32          LCN       Latin America & Caribbean  1960  55.146440  55.146440
# 33          LCN       Latin America & Caribbean  1980  63.681366        NaN
# 34          LCN       Latin America & Caribbean  2000  71.227714        NaN
# 35          LCN       Latin America & Caribbean  2020  73.038409        NaN
# 36          MEA      Middle East & North Africa  1960  44.757573  44.757573
# 37          MEA      Middle East & North Africa  1980  58.571006        NaN
# 38          MEA      Middle East & North Africa  2000  69.282178        NaN
# 39          MEA      Middle East & North Africa  2020  72.951079        NaN
# 40          NAC                   North America  1960  69.893606  69.893606
# 41          NAC                   North America  1980  73.752431        NaN
# 42          NAC                   North America  2000  76.881996        NaN
# 43          NAC                   North America  2020  77.741163        NaN
# 44          PSS     Pacific island small states  1960  54.526438  54.526438
# 45          PSS     Pacific island small states  1980  62.898881        NaN
# 46          PSS     Pacific island small states  2000  67.400452        NaN
# 47          PSS     Pacific island small states  2020  69.470610        NaN
# 48          SAS                      South Asia  1960  45.104840  45.104840
# 49          SAS                      South Asia  1980  53.759807        NaN
# 50          SAS                      South Asia  2000  62.892973        NaN
# 51          SAS                      South Asia  2020  69.748331        NaN
# 52          SSF              Sub-Saharan Africa  1960  41.422546  41.422546
# 53          SSF              Sub-Saharan Africa  1980  48.572456        NaN
# 54          SSF              Sub-Saharan Africa  2000  51.264545        NaN
# 55          SSF              Sub-Saharan Africa  2020  60.848891        NaN
#
#          1980       2000       2020
# 0         NaN        NaN        NaN
# 1   49.636538        NaN        NaN
# 2         NaN  51.964481        NaN
# 3         NaN        NaN  63.313856
# 4         NaN        NaN        NaN
# 5   47.015239        NaN        NaN
# 6         NaN  50.221954        NaN
# 7         NaN        NaN  57.226373
# 8         NaN        NaN        NaN
# 9   69.888985        NaN        NaN
# 10        NaN  72.719725        NaN
# 11        NaN        NaN  76.144034
# 12        NaN        NaN        NaN
# 13  67.350540        NaN        NaN
# 14        NaN  69.575544        NaN
# 15        NaN        NaN  72.574882
# 16        NaN        NaN        NaN
# 17  64.724662        NaN        NaN
# 18        NaN  71.552687        NaN
# 19        NaN        NaN  76.762681
# 20        NaN        NaN        NaN
# 21  70.284901        NaN        NaN
# 22        NaN  73.132098        NaN
# 23        NaN        NaN  77.025324
# 24        NaN        NaN        NaN
# 25  73.580654        NaN        NaN
# 26        NaN  78.270835        NaN
# 27        NaN        NaN  81.537122
# 28        NaN        NaN        NaN
# 29  72.789606        NaN        NaN
# 30        NaN  77.075317        NaN
# 31        NaN        NaN  80.465037
# 32        NaN        NaN        NaN
# 33  63.681366        NaN        NaN
# 34        NaN  71.227714        NaN
# 35        NaN        NaN  73.038409
# 36        NaN        NaN        NaN
# 37  58.571006        NaN        NaN
# 38        NaN  69.282178        NaN
# 39        NaN        NaN  72.951079
# 40        NaN        NaN        NaN
# 41  73.752431        NaN        NaN
# 42        NaN  76.881996        NaN
# 43        NaN        NaN  77.741163
# 44        NaN        NaN        NaN
# 45  62.898881        NaN        NaN
# 46        NaN  67.400452        NaN
# 47        NaN        NaN  69.470610
# 48        NaN        NaN        NaN
# 49  53.759807        NaN        NaN
# 50        NaN  62.892973        NaN
# 51        NaN        NaN  69.748331
# 52        NaN        NaN        NaN
# 53  48.572456        NaN        NaN
# 54        NaN  51.264545        NaN
# 55        NaN        NaN  60.848891

# %%
# make a new data frame with country_name and 1960, 1980, 2000, 2020 columns
country_data_new = country_data[['country_name', '1960', '1980', '2000', '2020']]

# %%
# remove columns 1980, 2000, 2020
country_data_1960_ = country_data_new.drop(columns=['1980', '2000', '2020'])


country_data_1980_ = country_data_new.drop(columns=['1960', '2000', '2020'])

country_data_2000_ = country_data_new.drop(columns=['1960', '1980', '2020'])

country_data_2020_ = country_data_new.drop(columns=['1960', '1980', '2000'])

# %%
# remove nan rows in country_data_1960_
country_data_1960_ = country_data_1960_.dropna()
# reset index
country_data_1960_ = country_data_1960_.reset_index(drop=True)

# remove nan rows in country_data_1980_
country_data_1980_ = country_data_1980_.dropna()
# reset index
country_data_1980_ = country_data_1980_.reset_index(drop=True)

# remove nan rows in country_data_2000_
country_data_2000_ = country_data_2000_.dropna()
# reset index
country_data_2000_ = country_data_2000_.reset_index(drop=True)

# remove nan rows in country_data_2020_
country_data_2020_ = country_data_2020_.dropna()
# reset index
country_data_2020_ = country_data_2020_.reset_index(drop=True)

# %%
country_data_2020_
# Out:
#                       country_name       2020
# 0      Africa Eastern and Southern  63.313856
# 1       Africa Western and Central  57.226373
# 2   Central Europe and the Baltics  76.144034
# 3           Caribbean small states  72.574882
# 4              East Asia & Pacific  76.762681
# 5            Europe & Central Asia  77.025324
# 6                        Euro area  81.537122
# 7                   European Union  80.465037
# 8        Latin America & Caribbean  73.038409
# 9       Middle East & North Africa  72.951079
# 10                   North America  77.741163
# 11     Pacific island small states  69.470610
# 12                      South Asia  69.748331
# 13              Sub-Saharan Africa  60.848891

# %%
# add 1960, 1980, 2000 columns to country_data_2020_
country_data_2020_['2000'] = country_data_2000_['2000']
country_data_2020_['1980'] = country_data_1980_['1980']
country_data_2020_['1960'] = country_data_1960_['1960']

country_data_2020_
# Out:
#                       country_name       2020       2000       1980       1960
# 0      Africa Eastern and Southern  63.313856  51.964481  49.636538  44.085552
# 1       Africa Western and Central  57.226373  50.221954  47.015239  37.845152
# 2   Central Europe and the Baltics  76.144034  72.719725  69.888985  67.933952
# 3           Caribbean small states  72.574882  69.575544  67.350540  61.952121
# 4              East Asia & Pacific  76.762681  71.552687  64.724662  41.641928
# 5            Europe & Central Asia  77.025324  73.132098  70.284901  67.514086
# 6                        Euro area  81.537122  78.270835  73.580654  69.284294
# 7                   European Union  80.465037  77.075317  72.789606  69.037606
# 8        Latin America & Caribbean  73.038409  71.227714  63.681366  55.146440
# 9       Middle East & North Africa  72.951079  69.282178  58.571006  44.757573
# 10                   North America  77.741163  76.881996  73.752431  69.893606
# 11     Pacific island small states  69.470610  67.400452  62.898881  54.526438
# 12                      South Asia  69.748331  62.892973  53.759807  45.104840
# 13              Sub-Saharan Africa  60.848891  51.264545  48.572456  41.422546

# %%
# Sort by 2020 column
country_data_2020_ = country_data_2020_.sort_values(by=['2020'], ascending=False)

# %%
# reset index
country_data_2020_ = country_data_2020_.reset_index(drop=True)

# %%
country_data_2020_
# Out:
#                       country_name       2020       2000       1980       1960
# 0                        Euro area  81.537122  78.270835  73.580654  69.284294
# 1                   European Union  80.465037  77.075317  72.789606  69.037606
# 2                    North America  77.741163  76.881996  73.752431  69.893606
# 3            Europe & Central Asia  77.025324  73.132098  70.284901  67.514086
# 4              East Asia & Pacific  76.762681  71.552687  64.724662  41.641928
# 5   Central Europe and the Baltics  76.144034  72.719725  69.888985  67.933952
# 6        Latin America & Caribbean  73.038409  71.227714  63.681366  55.146440
# 7       Middle East & North Africa  72.951079  69.282178  58.571006  44.757573
# 8           Caribbean small states  72.574882  69.575544  67.350540  61.952121
# 9                       South Asia  69.748331  62.892973  53.759807  45.104840
# 10     Pacific island small states  69.470610  67.400452  62.898881  54.526438
# 11     Africa Eastern and Southern  63.313856  51.964481  49.636538  44.085552
# 12              Sub-Saharan Africa  60.848891  51.264545  48.572456  41.422546
# 13      Africa Western and Central  57.226373  50.221954  47.015239  37.845152

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np

from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, FactorRange, Legend
from bokeh.plotting import figure

import seaborn as sns

output_notebook()
from bokeh.models import Range1d
from bokeh.plotting import figure, show, output_file
table = country_data_2020_.set_index('country_name')
source = ColumnDataSource(table)

p = figure(x_range=FactorRange(factors=table.index),
           plot_width=900,
           plot_height=675,
           title='Life expectancy by region in select years', 
           x_axis_label='Region', 
           y_axis_label='Years')

cmap = sns.color_palette('pastel', len(table.columns)).as_hex()

bar = {}
items = []

for i, crime in enumerate(list(table.columns)):
    bar[crime] = p.vbar(x='country_name', 
                    top=crime, 
                    source=source, 
                    width=0.7,
                    color=cmap[i],
                    fill_alpha=0.6,
                    muted=True, 
                    muted_alpha=0.005) 
    items.append((crime, [bar[crime]]))
bar['2020'].muted = False
bar['1960'].muted = False
p.xaxis.major_label_orientation = 1
p.y_range = Range1d(0, 100)

legend = Legend(items=items)
p.add_layout(legend, 'left')    
p.legend.click_policy = 'mute'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3876">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="803bf40a-7049-47dc-aaae-2396199a0f0f" data-root-id="3879"></div>

# %%
countries_ja = pd.read_csv('life_expectancy_by_countries_select.csv')
countries_ja
# Out:
#    country_code    country_name  year      value
# 0           DEU         Germany  1960  69.064073
# 1           DEU         Germany  1980  72.800317
# 2           DEU         Germany  2000  77.926829
# 3           DEU         Germany  2020  80.941463
# 4           ITA           Italy  1960  69.123902
# 5           ITA           Italy  1980  73.943171
# 6           ITA           Italy  2000  79.778049
# 7           ITA           Italy  2020  82.343902
# 8           JPN           Japan  1960  67.666098
# 9           JPN           Japan  1980  76.091707
# 10          JPN           Japan  2000  81.076098
# 11          JPN           Japan  2020  84.615610
# 12          DNK         Denmark  1960  72.176585
# 13          DNK         Denmark  1980  74.101707
# 14          DNK         Denmark  2000  76.592683
# 15          DNK         Denmark  2020  81.551220
# 16          USA   United States  1960  69.770732
# 17          USA   United States  1980  73.609756
# 18          USA   United States  2000  76.636585
# 19          USA   United States  2020  77.280488
# 20          GBR  United Kingdom  1960  71.126829
# 21          GBR  United Kingdom  1980  73.675610
# 22          GBR  United Kingdom  2000  77.741463
# 23          GBR  United Kingdom  2020  80.902439
# 24          AFG     Afghanistan  1960  32.535000
# 25          AFG     Afghanistan  1980  39.618000
# 26          AFG     Afghanistan  2000  55.298000
# 27          AFG     Afghanistan  2020  62.575000
# 28          IND           India  1960  45.218000
# 29          IND           India  1980  53.611000
# 30          IND           India  2000  62.669000
# 31          IND           India  2020  70.150000
# 32          VEN   Venezuela, RB  1960  58.647000
# 33          VEN   Venezuela, RB  1980  68.762000
# 34          VEN   Venezuela, RB  2000  72.478000
# 35          VEN   Venezuela, RB  2020  71.095000
# 36          AUS       Australia  1960  70.817073
# 37          AUS       Australia  1980  74.333659
# 38          AUS       Australia  2000  79.234146
# 39          AUS       Australia  2020  83.200000
# 40          KOR     Korea, Rep.  1960  54.320244
# 41          KOR     Korea, Rep.  1980  66.046341
# 42          KOR     Korea, Rep.  2000  75.909756
# 43          KOR     Korea, Rep.  2020  83.426829
# 44          CHN           China  1960  33.275000
# 45          CHN           China  1980  64.420000
# 46          CHN           China  2000  71.881000
# 47          CHN           China  2020  78.077000
# 48          CAN          Canada  1960  71.133171
# 49          CAN          Canada  1980  75.078049
# 50          CAN          Canada  2000  79.136585
# 51          CAN          Canada  2020  81.748780
# 52          SWE          Sweden  1960  73.005610
# 53          SWE          Sweden  1980  75.740976
# 54          SWE          Sweden  2000  79.643902
# 55          SWE          Sweden  2020  82.407317
# 56          WLD           World  1960  50.866171
# 57          WLD           World  1980  62.224853
# 58          WLD           World  2000  67.700054
# 59          WLD           World  2020  72.265011

# %%
# add columns 1960, 1980, 2000, 2020 with values from value column corresponding to year
countries_ja['1960'] = countries_ja['value'][countries_ja['year'] == 1960]
countries_ja['1980'] = countries_ja['value'][countries_ja['year'] == 1980]
countries_ja['2000'] = countries_ja['value'][countries_ja['year'] == 2000]
countries_ja['2020'] = countries_ja['value'][countries_ja['year'] == 2020]

# %%
# make a new data frame with country_name and 1960, 1980, 2000, 2020 columns
country_data_new_ja = countries_ja[['country_name', '1960', '1980', '2000', '2020']]

# %%
# remove columns 1980, 2000, 2020
country_data_1960_ja = country_data_new_ja.drop(columns=['1980', '2000', '2020'])


country_data_1980_ja = country_data_new_ja.drop(columns=['1960', '2000', '2020'])

country_data_2000_ja = country_data_new_ja.drop(columns=['1960', '1980', '2020'])

country_data_2020_ja = country_data_new_ja.drop(columns=['1960', '1980', '2000'])

# %%
# remove nan rows in country_data_1960_
country_data_1960_ja = country_data_1960_ja.dropna()
# reset index
country_data_1960_ja = country_data_1960_ja.reset_index(drop=True)

# remove nan rows in country_data_1980_
country_data_1980_ja = country_data_1980_ja.dropna()
# reset index
country_data_1980_ja = country_data_1980_ja.reset_index(drop=True)

# remove nan rows in country_data_2000_
country_data_2000_ja = country_data_2000_ja.dropna()
# reset index
country_data_2000_ja = country_data_2000_ja.reset_index(drop=True)

# remove nan rows in country_data_2020_
country_data_2020_ja = country_data_2020_ja.dropna()
# reset index
country_data_2020_ja = country_data_2020_ja.reset_index(drop=True)

# %%
country_data_2020_ja
# Out:
#       country_name       2020
# 0          Germany  80.941463
# 1            Italy  82.343902
# 2            Japan  84.615610
# 3          Denmark  81.551220
# 4    United States  77.280488
# 5   United Kingdom  80.902439
# 6      Afghanistan  62.575000
# 7            India  70.150000
# 8    Venezuela, RB  71.095000
# 9        Australia  83.200000
# 10     Korea, Rep.  83.426829
# 11           China  78.077000
# 12          Canada  81.748780
# 13          Sweden  82.407317
# 14           World  72.265011

# %%
# add 1960, 1980, 2000 columns to country_data_2020_
country_data_2020_ja['2000'] = country_data_2000_ja['2000']
country_data_2020_ja['1980'] = country_data_1980_ja['1980']
country_data_2020_ja['1960'] = country_data_1960_ja['1960']

country_data_2020_ja
# Out:
#       country_name       2020       2000       1980       1960
# 0          Germany  80.941463  77.926829  72.800317  69.064073
# 1            Italy  82.343902  79.778049  73.943171  69.123902
# 2            Japan  84.615610  81.076098  76.091707  67.666098
# 3          Denmark  81.551220  76.592683  74.101707  72.176585
# 4    United States  77.280488  76.636585  73.609756  69.770732
# 5   United Kingdom  80.902439  77.741463  73.675610  71.126829
# 6      Afghanistan  62.575000  55.298000  39.618000  32.535000
# 7            India  70.150000  62.669000  53.611000  45.218000
# 8    Venezuela, RB  71.095000  72.478000  68.762000  58.647000
# 9        Australia  83.200000  79.234146  74.333659  70.817073
# 10     Korea, Rep.  83.426829  75.909756  66.046341  54.320244
# 11           China  78.077000  71.881000  64.420000  33.275000
# 12          Canada  81.748780  79.136585  75.078049  71.133171
# 13          Sweden  82.407317  79.643902  75.740976  73.005610
# 14           World  72.265011  67.700054  62.224853  50.866171

# %%
# Sort by 2020 column
country_data_2020_ja = country_data_2020_ja.sort_values(by=['2020'], ascending=False)

# %%
country_data_2020_ja = country_data_2020_ja.reset_index(drop=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np

from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, FactorRange, Legend
from bokeh.plotting import figure

import seaborn as sns

output_notebook()
from bokeh.models import Range1d
from bokeh.plotting import figure, show, output_file
table = country_data_2020_ja.set_index('country_name')
source = ColumnDataSource(table)

p_c = figure(x_range=FactorRange(factors=table.index),
           plot_width=900,
           plot_height=675,
           title='Life expectancy by country in select years', 
           x_axis_label='Country', 
           y_axis_label='Years')

cmap = sns.color_palette('pastel', len(table.columns)).as_hex()

bar = {}
items = []

for i, crime in enumerate(list(table.columns)):
    bar[crime] = p_c.vbar(x='country_name', 
                    top=crime, 
                    source=source, 
                    width=0.7,
                    color=cmap[i],
                    fill_alpha=0.6,
                    muted=True, 
                    muted_alpha=0.005) 
    items.append((crime, [bar[crime]]))
bar['2020'].muted = False
bar['1960'].muted = False
p_c.xaxis.major_label_orientation = 1
p_c.y_range = Range1d(0, 100)

legend = Legend(items=items)
p_c.add_layout(legend, 'left')    
p_c.legend.click_policy = 'mute'
show(p_c)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4173">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="501ce71c-b382-440d-bfff-99e44d2c2897" data-root-id="4176"></div>

# %%
from bokeh.io import show
from bokeh.models import Panel, Tabs
from bokeh.plotting import figure

tab1 = Panel(child=p, title="Regions")
tab2 = Panel(child=p_c, title="Countries")
output_file('bokeh.html')
show(Tabs(tabs=[tab1, tab2]))
# Out:
#   <div class="bk-root" id="517ddf49-e6d8-474d-b981-22e92c02bbfb" data-root-id="4480"></div>

# %%
afghanistan = pd.read_csv('data/Afghanistan-2023.csv')
afghanistan['Afghanistan'] = afghanistan['M'] + afghanistan['F']

australia = pd.read_csv('data/Australia-2023.csv')
australia['Australia'] = australia['M'] + australia['F']

canada = pd.read_csv('data/Canada-2023.csv')
canada['Canada'] = canada['M'] + canada['F']

china = pd.read_csv('data/China-2023.csv')
china['China'] = china['M'] + china['F']

denmark = pd.read_csv('data/Denmark-2023.csv')
denmark['Denmark'] = denmark['M'] + denmark['F']

germany = pd.read_csv('data/Germany-2023.csv')
germany['Germany'] = germany['M'] + germany['F']

india = pd.read_csv('data/India-2023.csv')
india['India'] = india['M'] + india['F']

italy = pd.read_csv('data/Italy-2023.csv')
italy['Italy'] = italy['M'] + italy['F']

japan = pd.read_csv('data/Japan-2023.csv')
japan['Japan'] = japan['M'] + japan['F']

korea = pd.read_csv('data/Republic of Korea-2023.csv')
korea['South Korea'] = korea['M'] + korea['F']

sweden = pd.read_csv('data/Sweden-2023.csv')
sweden['Sweden'] = sweden['M'] + sweden['F']

uk = pd.read_csv('data/United Kingdom-2023.csv')
uk['United Kingdom'] = uk['M'] + uk['F']

us = pd.read_csv('data/United States of America-2023.csv')
us['United States'] = us['M'] + us['F']

venezuela = pd.read_csv('data/Venezuela-2023.csv')
venezuela['Venezuela'] = venezuela['M'] + venezuela['F']

world = pd.read_csv('data/WORLD-2023.csv')
world['World'] = world['M'] + world['F']

# %%
# create new dataframe with columns: Age, Afghanistan, Australia, Canada, China, Denmark, Germany, India, Italy, Japan, Korea, Sweden, UK, US, Venezuela, World
df = pd.DataFrame(columns=['Age', 'Afghanistan', 'Australia', 'Canada', 'China', 'Denmark', 'Germany', 'India', 'Italy', 'Japan', 'South Korea', 'Sweden', 'United Kingdom', 'United States', 'Venezuela', 'World'])

# add age column
df['Age'] = afghanistan['Age']

# add country columns
df['Afghanistan'] = afghanistan['Afghanistan']
df['Australia'] = australia['Australia']
df['Canada'] = canada['Canada']
df['China'] = china['China']
df['Denmark'] = denmark['Denmark']
df['Germany'] = germany['Germany']
df['India'] = india['India']
df['Italy'] = italy['Italy']
df['Japan'] = japan['Japan']
df['South Korea'] = korea['South Korea']
df['Sweden'] = sweden['Sweden']
df['United Kingdom'] = uk['United Kingdom']
df['United States'] = us['United States']
df['Venezuela'] = venezuela['Venezuela']
df['World'] = world['World']

# replace each value in country name columns with percent of sum of column
df['Afghanistan'] = (df['Afghanistan'] / df['Afghanistan'].sum()) * 100
df['Australia'] = (df['Australia'] / df['Australia'].sum()) * 100
df['Canada'] = (df['Canada'] / df['Canada'].sum()) * 100
df['China'] = (df['China'] / df['China'].sum()) * 100
df['Denmark'] = (df['Denmark'] / df['Denmark'].sum()) * 100
df['Germany'] = (df['Germany'] / df['Germany'].sum()) * 100
df['India'] = (df['India'] / df['India'].sum()) * 100
df['Italy'] = (df['Italy'] / df['Italy'].sum()) * 100
df['Japan'] = (df['Japan'] / df['Japan'].sum()) * 100
df['South Korea'] = (df['South Korea'] / df['South Korea'].sum()) * 100
df['Sweden'] = (df['Sweden'] / df['Sweden'].sum()) * 100
df['United Kingdom'] = (df['United Kingdom'] / df['United Kingdom'].sum()) * 100
df['United States'] = (df['United States'] / df['United States'].sum()) * 100
df['Venezuela'] = (df['Venezuela'] / df['Venezuela'].sum()) * 100
df['World'] = (df['World'] / df['World'].sum()) * 100

df
# Out:
#       Age  Afghanistan  Australia    Canada     China   Denmark   Germany  \
# 0     0-4    15.923752   5.769197  4.904415  4.288830  5.350318  4.658313
# 1     5-9    14.359987   6.068080  5.140111  6.222828  5.169990  4.819871
# 2   10-14    12.561384   6.142391  5.360695  6.276288  5.426668  4.510555
# 3   15-19    11.531061   5.923007  5.376720  5.741906  5.860579  4.568692
# 4   20-24    10.061759   6.152890  6.103955  5.571805  6.180682  5.209333
# 5   25-29     8.369098   7.191602  6.873342  6.048752  6.864926  5.816404
# 6   30-34     6.533192   7.559553  7.115789  7.892754  6.712327  6.474024
# 7   35-39     4.948783   7.347485  6.949585  7.984188  5.867786  6.524188
# 8   40-44     3.970914   6.699906  6.706811  6.991699  5.726741  6.323715
# 9   45-49     3.294371   6.135023  6.250544  6.899895  6.363260  5.794090
# 10  50-54     2.612581   6.328577  6.220156  8.583773  6.586018  6.845322
# 11  55-59     1.982370   5.764367  6.585827  7.992872  7.063339  8.156273
# 12  60-64     1.455616   5.683377  6.866305  5.237798  6.108290  7.552297
# 13  65-69     1.029838   4.992563  6.089539  5.335504  5.504135  6.155824
# 14  70-74     0.677555   4.336157  4.941735  4.105631  5.044020  5.224480
# 15  75-79     0.425338   3.492187  3.765425  2.354873  4.862406  3.811265
# 16  80-84     0.189267   2.238627  2.382719  1.407161  2.957113  4.004829
# 17  85-89     0.060109   1.328971  1.415505  0.753763  1.555364  2.381048
# 18  90-94     0.011816   0.624617  0.702326  0.259254  0.610212  0.895070
# 19  95-99     0.001172   0.193974  0.214034  0.046745  0.163647  0.243710
# 20   100+     0.000038   0.027448  0.034463  0.003681  0.022179  0.030696
#
#        India     Italy     Japan  South Korea    Sweden  United Kingdom  \
# 0   7.913128  3.512775  3.347315     2.879655  5.499387        5.132379
# 1   8.286273  4.056298  3.873204     3.923737  5.910758        5.888484
# 2   8.700930  4.629318  4.248369     4.431672  6.009768        6.195807
# 3   8.854024  4.850089  4.449450     4.410992  5.842581        5.819709
# 4   8.940509  4.964141  4.824960     5.605120  5.633216        5.719130
# 5   8.572811  5.095868  4.964327     6.874976  6.166580        6.456224
# 6   8.134528  5.468891  5.040741     6.757925  7.414480        6.797601
# 7   7.595274  5.686117  5.533421     6.527118  6.667199        6.610253
# 8   6.747502  6.301518  6.110609     7.859150  6.162104        6.452710
# 9   5.945231  7.513135  7.381913     7.607839  6.126211        5.912047
# 10  5.184765  8.094120  7.556613     8.647306  6.242183        6.592053
# 11  4.406013  8.186334  6.590862     7.965399  6.428753        6.784065
# 12  3.646904  7.181094  6.010588     8.130722  5.470288        6.181282
# 13  2.866947  6.192722  5.889343     6.340551  5.128225        5.206735
# 14  2.010241  5.591045  7.200658     4.306533  4.912009        4.691291
# 15  1.141601  4.813968  6.160240     3.159390  4.736492        4.228929
# 16  0.638806  3.839105  4.956307     2.515848  3.012541        2.651484
# 17  0.291805  2.515594  3.370341     1.357974  1.665480        1.665649
# 18  0.097643  1.166545  1.758957     0.545707  0.746989        0.758817
# 19  0.022053  0.304151  0.618177     0.133628  0.199556        0.220092
# 20  0.003013  0.037171  0.113605     0.018757  0.025198        0.035260
#
#     United States  Venezuela     World
# 0        5.521237   7.853581  8.161775
# 1        5.960592   9.143957  8.486074
# 2        6.193003   9.740258  8.352002
# 3        6.587992   9.577534  7.902977
# 4        6.573251   8.000711  7.549437
# 5        6.622635   6.580158  7.357315
# 6        7.013568   6.438455  7.490917
# 7        6.717772   6.469351  7.176767
# 8        6.526189   6.371423  6.501781
# 9        5.984306   6.045865  5.898449
# 10       6.241244   5.560229  5.746895
# 11       6.180324   5.057893  5.154192
# 12       6.289968   4.346306  4.180908
# 13       5.685644   3.433713  3.582645
# 14       4.498262   2.385496  2.720244
# 15       3.357348   1.616832  1.743542
# 16       2.062958   0.928693  1.097297
# 17       1.196169   0.361545  0.595075
# 18       0.599679   0.080334  0.234867
# 19       0.157182   0.007563  0.058419
# 20       0.030677   0.000104  0.008422

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np

from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, FactorRange, Legend
from bokeh.plotting import figure

import seaborn as sns

output_notebook()
from bokeh.models import Range1d
from bokeh.plotting import figure, show, output_file
table = df.set_index('Age')
source = ColumnDataSource(table)

p = figure(x_range=FactorRange(factors=table.index),
           plot_width=900,
           plot_height=675,
           title='Population Distribution by Age in 2022', 
           x_axis_label='Age', 
           y_axis_label='%')

cmap = sns.color_palette('pastel', len(table.columns)).as_hex()

bar = {}
items = []

for i, crime in enumerate(list(table.columns)):
    bar[crime] = p.vbar(x='Age', 
                    top=crime, 
                    source=source, 
                    width=0.7,
                    color=cmap[i],
                    fill_alpha=0.6,
                    muted=True, 
                    muted_alpha=0.005) 
    items.append((crime, [bar[crime]]))
bar['Germany'].muted = False
bar['Japan'].muted = False
bar['Afghanistan'].muted = False
p.xaxis.major_label_orientation = 1
p.y_range = Range1d(0, 20)

legend = Legend(items=items)
p.add_layout(legend, 'left')    
p.legend.click_policy = 'mute'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4866">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="893e8ea1-41c5-4a5f-9990-6c0af2943b9b" data-root-id="4869"></div>

# %%
afghanistan_1960 = pd.read_csv('data/Afghanistan-1960.csv')
afghanistan_1960['Afghanistan'] = afghanistan_1960['M'] + afghanistan_1960['F']

australia_1960 = pd.read_csv('data/Australia-1960.csv')
australia_1960['Australia'] = australia_1960['M'] + australia_1960['F']

canada_1960 = pd.read_csv('data/Canada-1960.csv')
canada_1960['Canada'] = canada_1960['M'] + canada_1960['F']

china_1960 = pd.read_csv('data/China-1960.csv')
china_1960['China'] = china_1960['M'] + china_1960['F']

denmark_1960 = pd.read_csv('data/Denmark-1960.csv')
denmark_1960['Denmark'] = denmark_1960['M'] + denmark_1960['F']

germany_1960 = pd.read_csv('data/Germany-1960.csv')
germany_1960['Germany'] = germany_1960['M'] + germany_1960['F']

india_1960 = pd.read_csv('data/India-1960.csv')
india_1960['India'] = india_1960['M'] + india_1960['F']

italy_1960 = pd.read_csv('data/Italy-1960.csv')
italy_1960['Italy'] = italy_1960['M'] + italy_1960['F']

japan_1960 = pd.read_csv('data/Japan-1960.csv')
japan_1960['Japan'] = japan_1960['M'] + japan_1960['F']

korea_1960 = pd.read_csv('data/Republic of Korea-1960.csv')
korea_1960['South Korea'] = korea_1960['M'] + korea_1960['F']

sweden_1960 = pd.read_csv('data/Sweden-1960.csv')
sweden_1960['Sweden'] = sweden_1960['M'] + sweden_1960['F']

uk_1960 = pd.read_csv('data/United Kingdom-1960.csv')
uk_1960['United Kingdom'] = uk_1960['M'] + uk_1960['F']

us_1960= pd.read_csv('data/United States of America-1960.csv')
us_1960['United States'] = us_1960['M'] + us_1960['F']

venezuela_1960 = pd.read_csv('data/Venezuela-1960.csv')
venezuela_1960['Venezuela'] = venezuela_1960['M'] + venezuela_1960['F']

world_1960 = pd.read_csv('data/WORLD-1960.csv')
world_1960['World'] = world_1960['M'] + world_1960['F']

# %%
# create new dataframe with columns: Age, Afghanistan, Australia, Canada, China, Denmark, Germany, India, Italy, Japan, Korea, Sweden, UK, US, Venezuela, World
df_1960 = pd.DataFrame(columns=['Age', 'Afghanistan', 'Australia', 'Canada', 'China', 'Denmark', 'Germany', 'India', 'Italy', 'Japan', 'South Korea', 'Sweden', 'United Kingdom', 'United States', 'Venezuela', 'World'])

# add age column
df_1960['Age'] = afghanistan_1960['Age']

# add country columns
df_1960['Afghanistan'] = afghanistan_1960['Afghanistan']
df_1960['Australia'] = australia_1960['Australia']
df_1960['Canada'] = canada_1960['Canada']
df_1960['China'] = china_1960['China']
df_1960['Denmark'] = denmark_1960['Denmark']
df_1960['Germany'] = germany_1960['Germany']
df_1960['India'] = india_1960['India']
df_1960['Italy'] = italy_1960['Italy']
df_1960['Japan'] = japan_1960['Japan']
df_1960['South Korea'] = korea_1960['South Korea']
df_1960['Sweden'] = sweden_1960['Sweden']
df_1960['United Kingdom'] = uk_1960['United Kingdom']
df_1960['United States'] = us_1960['United States']
df_1960['Venezuela'] = venezuela_1960['Venezuela']
df_1960['World'] = world_1960['World']

# replace each value in country name columns with percent of sum of column
df_1960['Afghanistan'] = (df_1960['Afghanistan'] / df_1960['Afghanistan'].sum()) * 100
df_1960['Australia'] = (df_1960['Australia'] / df_1960['Australia'].sum()) * 100
df_1960['Canada'] = (df_1960['Canada'] / df_1960['Canada'].sum()) * 100
df_1960['China'] = (df_1960['China'] / df_1960['China'].sum()) * 100
df_1960['Denmark'] = (df_1960['Denmark'] / df_1960['Denmark'].sum()) * 100
df_1960['Germany'] = (df_1960['Germany'] / df_1960['Germany'].sum()) * 100
df_1960['India'] = (df_1960['India'] / df_1960['India'].sum()) * 100
df_1960['Italy'] = (df_1960['Italy'] / df_1960['Italy'].sum()) * 100
df_1960['Japan'] = (df_1960['Japan'] / df_1960['Japan'].sum()) * 100
df_1960['South Korea'] = (df_1960['South Korea'] / df_1960['South Korea'].sum()) * 100
df_1960['Sweden'] = (df_1960['Sweden'] / df_1960['Sweden'].sum()) * 100
df_1960['United Kingdom'] = (df_1960['United Kingdom'] / df_1960['United Kingdom'].sum()) * 100
df_1960['United States'] = (df_1960['United States'] / df_1960['United States'].sum()) * 100
df_1960['Venezuela'] = (df_1960['Venezuela'] / df_1960['Venezuela'].sum()) * 100
df_1960['World'] = (df_1960['World'] / df_1960['World'].sum()) * 100

df_1960
# Out:
#       Age  Afghanistan  Australia     Canada      China   Denmark   Germany  \
# 0     0-4    16.932057  10.632834  12.420199  15.044834  7.995281  7.803955
# 1     5-9    12.865489  10.027281  11.358998  14.663854  8.089940  7.030530
# 2   10-14    11.829670   9.532445   9.953838  10.635971  9.100173  6.222509
# 3   15-19    10.298552   7.468427   7.705358   8.249180  8.313023  7.230944
# 4   20-24     8.944402   6.517397   6.579605   7.899032  6.626187  8.493361
# 5   25-29     7.713256   6.374338   6.787602   7.530149  6.088615  6.778944
# 6   30-34     6.671221   7.226210   7.106403   6.564253  6.255081  6.798410
# 7   35-39     5.609748   7.357798   6.966945   5.868593  6.804330  6.607941
# 8   40-44     4.688085   6.422186   6.163481   5.133161  6.545322  4.570821
# 9   45-49     3.895979   6.298959   5.548400   4.587313  6.681734  6.867350
# 10  50-54     3.178805   5.326522   4.684868   3.992655  6.377721  7.383506
# 11  55-59     2.582513   4.433305   3.862129   3.378370  5.633633  6.964739
# 12  60-64     1.957227   3.805714   3.190296   2.485333  4.885594  5.717664
# 13  65-69     1.392678   3.242333   2.684934   1.828755  3.920846  4.425779
# 14  70-74     0.848111   2.511997   2.219350   1.167957  3.005425  3.335639
# 15  75-79     0.413954   1.542059   1.489865   0.631245  2.051939  2.170077
# 16  80-84     0.143149   0.842773   0.831599   0.245161  1.111134  1.141534
# 17  85-89     0.031198   0.332042   0.334356   0.076573  0.408930  0.385640
# 18  90-94     0.003700   0.089981   0.093895   0.015809  0.093284  0.064709
# 19  95-99     0.000209   0.014397   0.016366   0.001716  0.011131  0.005701
# 20   100+     0.000000   0.001001   0.001513   0.000086  0.000677  0.000246
#
#         India     Italy      Japan  South Korea    Sweden  United Kingdom  \
# 0   16.368302  8.395175   8.327977    17.838993  6.962609        7.942256
# 1   13.437823  8.060203   9.574571    13.114224  7.177279        7.279582
# 2   10.714516  8.554780  11.591744    10.956534  8.280673        8.137321
# 3    9.068665  7.411227  10.015281    10.321287  7.678208        6.900182
# 4    8.423423  7.745084   9.067646     9.802813  6.159313        6.320881
# 5    7.568913  7.470545   8.935470     7.111304  5.869705        6.217676
# 6    6.706616  7.582722   8.154333     5.698228  6.352416        6.499425
# 7    5.871812  7.533594   6.533347     5.397153  7.293003        7.158302
# 8    5.139307  5.091760   5.347772     4.483700  7.037800        6.422807
# 9    4.408403  6.852086   5.144143     3.944217  7.170766        7.031591
# 10   3.772152  6.231447   4.485051     3.457176  6.923038        6.882105
# 11   2.890738  5.205436   3.876930     2.433588  6.119756        6.285575
# 12   2.337865  4.354148   3.146468     2.136685  5.230899        5.197995
# 13   1.458946  3.513754   2.335571     1.592915  4.282438        4.220415
# 14   1.058052  2.776727   1.702582     1.085825  3.349019        3.291414
# 15   0.459079  1.847192   1.042787     0.457767  2.250029        2.276568
# 16   0.228009  0.955893   0.501642     0.140966  1.263132        1.300373
# 17   0.071644  0.334373   0.170821     0.020540  0.473316        0.501321
# 18   0.014103  0.073974   0.040045     0.005066  0.109330        0.116805
# 19   0.001534  0.009397   0.005440     0.000825  0.016242        0.016227
# 20   0.000097  0.000485   0.000378     0.000194  0.001028        0.001178
#
#     United States  Venezuela      World
# 0       11.205866  19.317069  14.441357
# 1       10.541510  15.419816  12.592004
# 2        9.067685  12.128638  10.335747
# 3        7.267915   9.813305   8.534788
# 4        6.147632   8.231152   8.198293
# 5        6.254007   7.172494   7.475503
# 6        6.888203   6.197028   6.923293
# 7        6.846752   5.212871   6.036058
# 8        6.400184   4.300333   5.014504
# 9        6.093990   3.493706   4.818018
# 10       5.336098   2.789887   4.248976
# 11       4.679153   2.124121   3.564112
# 12       4.040567   1.520879   2.796786
# 13       3.404517   1.027532   2.062272
# 14       2.664399   0.648639   1.470085
# 15       1.713587   0.368055   0.864911
# 16       0.923363   0.169758   0.424130
# 17       0.391151   0.050644   0.154355
# 18       0.111498   0.011107   0.037839
# 19       0.019520   0.002366   0.006300
# 20       0.002403   0.000601   0.000669

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np

from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, FactorRange, Legend
from bokeh.plotting import figure

import seaborn as sns

output_notebook()
from bokeh.models import Range1d
from bokeh.plotting import figure, show, output_file
table = df_1960.set_index('Age')
source = ColumnDataSource(table)

p_1960 = figure(x_range=FactorRange(factors=table.index),
           plot_width=900,
           plot_height=675,
           title='Population Distribution by Age in 1960', 
           x_axis_label='Age', 
           y_axis_label='%')

cmap = sns.color_palette('pastel', len(table.columns)).as_hex()

bar = {}
items = []

for i, crime in enumerate(list(table.columns)):
    bar[crime] = p_1960.vbar(x='Age', 
                    top=crime, 
                    source=source, 
                    width=0.7,
                    color=cmap[i],
                    fill_alpha=0.6,
                    muted=True, 
                    muted_alpha=0.005) 
    items.append((crime, [bar[crime]]))
bar['Germany'].muted = False
bar['Japan'].muted = False
bar['Afghanistan'].muted = False
p_1960.xaxis.major_label_orientation = 1
p_1960.y_range = Range1d(0, 20)

legend = Legend(items=items)
p_1960.add_layout(legend, 'left')    
p_1960.legend.click_policy = 'mute'
show(p_1960)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5272">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d5411db4-69a7-423f-acb2-46ced3bc2b59" data-root-id="5275"></div>

# %%
from bokeh.io import show
from bokeh.models import Panel, Tabs
from bokeh.plotting import figure

tab1 = Panel(child=p, title="2022")
tab2 = Panel(child=p_1960, title="1960")
output_file('age.html')
show(Tabs(tabs=[tab2, tab1]))
# Out:
#   <div class="bk-root" id="d145dd81-00ea-4070-93c8-a17e061bfac3" data-root-id="5688"></div>

# %%
import bokeh
import bokeh.plotting

bokeh.io.output_notebook()

x = [x*0.005 for x in range(0, 200)]
y = x

source = bokeh.models.ColumnDataSource(data=dict(x=x, y=y))

plot = bokeh.plotting.figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

def callback(source=source, window=None):
    data = source.data
    m = cb_obj.active
    if m==0:
        f=.5
    else:
        f=2

    x, y = data['x'], data['y']
    for i in range(len(x)):
        y[i] = window.Math.pow(x[i], f)
    source.trigger('change')

input1 = bokeh.models.RadioGroup(labels=["power = .5", "power = 2."],active=0,
                   callback=bokeh.models.CustomJS.from_py_func(callback))

layout = bokeh.layouts.column(input1, plot)

bokeh.io.show(layout)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6106">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-3713f96070c6> in <module>
#      26
#      27 input1 = bokeh.models.RadioGroup(labels=["power = .5", "power = 2."],active=0,
# ---> 28                    callback=bokeh.models.CustomJS.from_py_func(callback))
#      29
#      30 layout = bokeh.layouts.column(input1, plot)
#
# AttributeError: type object 'CustomJS' has no attribute 'from_py_func'

# %%
import bokeh
import bokeh.plotting

bokeh.io.output_notebook()

x = [x*0.005 for x in range(0, 200)]
y = x

source = bokeh.models.ColumnDataSource(data=dict(x=x, y=y))

plot = bokeh.plotting.figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

def callback(source=source, window=None):
    data = source.data
    m = cb_obj.active
    if m==0:
        f=.5
    else:
        f=2

    x, y = data['x'], data['y']
    for i in range(len(x)):
        y[i] = window.Math.pow(x[i], f)
    source.trigger('change')

input1 = bokeh.models.RadioGroup(labels=["power = .5", "power = 2."],active=0,
                   callback=bokeh.models.CustomJS.from_py_func(callback))

layout = bokeh.layouts.column(input1, plot)

bokeh.io.show(layout)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-3713f96070c6> in <module>
#       2 import bokeh.plotting
#       3
# ----> 4 bokeh.io.output_notebook()
#       5
#       6 x = [x*0.005 for x in range(0, 200)]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/output.py in output_notebook(resources, verbose, hide_banner, load_timeout, notebook_type)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/notebook.py in run_notebook_hook(notebook_type, action, *args, **kw)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/notebook.py in load_notebook(resources, verbose, hide_banner, load_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/notebook.py in _loading_js(bundle, element_id, load_timeout, register_mime)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jinja2/environment.py in render(self, *args, **kwargs)
#    1088             return concat(self.root_render_func(self.new_context(vars)))
#    1089         except Exception:
# -> 1090             self.environment.handle_exception()
#    1091
#    1092     def render_async(self, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jinja2/environment.py in handle_exception(self, source)
#     830         from .debug import rewrite_traceback_stack
#     831
# --> 832         reraise(*rewrite_traceback_stack(source=source))
#     833
#     834     def join_path(self, template, parent):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jinja2/_compat.py in reraise(tp, value, tb)
#      26     def reraise(tp, value, tb=None):
#      27         if value.__traceback__ is not tb:
# ---> 28             raise value.with_traceback(tb)
#      29         raise value
#      30
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/_templates/autoload_nb_js.js in top-level template code()
# ----> 1 {% extends "autoload_js.js" %}
#       2
#       3 {% block autoload_init %}
#       4   if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       5     window._bokeh_timeout = Date.now() + {{ timeout|default(0)|json }};
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/_templates/autoload_js.js in top-level template code()
#      78   {%- endif %}
#      79
# ---> 80   var js_urls = {{ js_urls|json }};
#      81
#      82   var inline_js = [
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/templates.py in <lambda>(obj)
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~/opt/anaconda3/lib/python3.8/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~/opt/anaconda3/lib/python3.8/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~/opt/anaconda3/lib/python3.8/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type Undefined is not JSON serializable

# %%
pip install Bokeh==0.12.5
# Out:
# Collecting Bokeh==0.12.5
#   Downloading bokeh-0.12.5.tar.gz (7.0 MB)
#      |████████████████████████████████| 7.0 MB 447 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.5.2 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Bokeh==0.12.5) (1.15.0)
# Requirement already satisfied: requests>=1.2.3 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Bokeh==0.12.5) (2.28.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Bokeh==0.12.5) (5.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Bokeh==0.12.5) (2.8.2)
# Requirement already satisfied: Jinja2>=2.7 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Bokeh==0.12.5) (2.11.2)
# Requirement already satisfied: numpy>=1.7.1 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Bokeh==0.12.5) (1.19.0)
# Requirement already satisfied: tornado>=4.3 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Bokeh==0.12.5) (6.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from requests>=1.2.3->Bokeh==0.12.5) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from requests>=1.2.3->Bokeh==0.12.5) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from requests>=1.2.3->Bokeh==0.12.5) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from requests>=1.2.3->Bokeh==0.12.5) (2.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.7->Bokeh==0.12.5) (2.0.1)
# Building wheels for collected packages: Bokeh
#   Building wheel for Bokeh (setup.py) ... done
#   Created wheel for Bokeh: filename=bokeh-0.12.5-py3-none-any.whl size=5431272 sha256=29a2187e84b97c6c28162ba5aa94f397f4f014e9df6f030bc40dfbba27198f42
#   Stored in directory: /Users/huayuan/Library/Caches/pip/wheels/02/8d/30/f2c53c46d2d7b0c658bc286a78fe5a5e338c43a5b20a950cb1
# Successfully built Bokeh
# Installing collected packages: Bokeh
#   Attempting uninstall: Bokeh
#     Found existing installation: bokeh 2.2.3
#     Uninstalling bokeh-2.2.3:
#       Successfully uninstalled bokeh-2.2.3
# Successfully installed Bokeh-0.12.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bokeh==2.2.3
# Out:
# Collecting bokeh==2.2.3
#   Downloading bokeh-2.2.3.tar.gz (8.8 MB)
#      |████████████████████████████████| 8.8 MB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: PyYAML>=3.10 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (5.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (2.8.2)
# Requirement already satisfied: Jinja2>=2.7 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (2.11.2)
# Requirement already satisfied: numpy>=1.11.3 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (1.19.0)
# Requirement already satisfied: pillow>=7.1.0 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (8.0.1)
# Requirement already satisfied: packaging>=16.8 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (20.4)
# Requirement already satisfied: tornado>=5.1 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (6.2)
# Requirement already satisfied: typing_extensions>=3.7.4 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.2.3) (4.4.0)
# Requirement already satisfied: six>=1.5 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.1->bokeh==2.2.3) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.7->bokeh==2.2.3) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages (from packaging>=16.8->bokeh==2.2.3) (2.4.7)
# Building wheels for collected packages: bokeh
#   Building wheel for bokeh (setup.py) ... done
#   Created wheel for bokeh: filename=bokeh-2.2.3-py3-none-any.whl size=9296308 sha256=940905e2de60d1cfbe5331777134810d150facaccabf4b55ef177590f396beba
#   Stored in directory: /Users/huayuan/Library/Caches/pip/wheels/44/48/ac/5cde9e6d0b1e0afb4cff564eaf59462468abe37cfc83cbb5ed
# Successfully built bokeh
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 0.12.5
#     Uninstalling bokeh-0.12.5:
#       Successfully uninstalled bokeh-0.12.5
# Successfully installed bokeh-2.2.3
# Note: you may need to restart the kernel to use updated packages.
